# %% [markdown]
# ## Text Sequence Prediction

# %% [markdown]
# ### A dataset consisting of multiple text sentence

# %%
import warnings
warnings.filterwarnings('ignore')
import re

# %%
text_data = """
Long Short-Term Memory Networks is a deep learning, sequential neural network that allows information to persist. It is a special type of Recurrent Neural Network which is capable of handling the vanishing gradient problem faced by RNN. LSTM was designed by Hochreiter and Schmidhuber that resolves the problem caused by traditional rnns and machine learning algorithms. LSTM can be implemented in Python using the Keras library.

Let’s say while watching a video, you remember the previous scene, or while reading a book, you know what happened in the earlier chapter. RNNs work similarly; they remember the previous information and use it for processing the current input. The shortcoming of RNN is they cannot remember long-term dependencies due to vanishing gradient. LSTMs are explicitly designed to avoid long-term dependency problems.

This article will cover all the basics about LSTM, including its meaning, architecture, applications, and gates.

Learning Objectives
Understand what LSTM is.
Understand the architecture and working of an LSTM network.
Learn about the different parts/gates in an LSTM unit.
Note: If you are more interested in learning concepts in an Audio-Visual format, We have the tutorial of this entire article explained in the video below. If not, you may continue reading.

Table of contents
What is LSTM?
LSTM Architecture
Forget Gate
Input Gate
New Information
Output Gate
LTSM vs RNN
What are Bidirectional LSTMs?
Conclusion
Frequently Asked Questions
What is LSTM?
LSTM (Long Short-Term Memory) is a recurrent neural network (RNN) architecture widely used in Deep Learning. It excels at capturing long-term dependencies, making it ideal for sequence prediction tasks.

Unlike traditional neural networks, LSTM incorporates feedback connections, allowing it to process entire sequences of data, not just individual data points. This makes it highly effective in understanding and predicting patterns in sequential data like time series, text, and speech.
In the introduction to long short-term memory, we learned that it resolves the vanishing gradient problem faced by RNN, so now, in this section, we will see how it resolves this problem by learning the architecture of the LSTM. At a high level, LSTM works very much like an RNN cell. Here is the internal functioning of the LSTM network. The LSTM network architecture consists of three parts, as shown in the image below, and each part performs an individual function.

The first part chooses whether the information coming from the previous timestamp is to be remembered or is irrelevant and can be forgotten. In the second part, the cell tries to learn new information from the input to this cell. At last, in the third part, the cell passes the updated information from the current timestamp to the next timestamp. This one cycle of LSTM is considered a single-time step.

These three parts of an LSTM unit are known as gates. They control the flow of information in and out of the memory cell or lstm cell. The first gate is called Forget gate, the second gate is known as the Input gate, and the last one is the Output gate. An LSTM unit that consists of these three gates and a memory cell or lstm cell can be considered as a layer of neurons in traditional feedforward neural network, with each neuron having a hidden layer and a current state.

Just like a simple RNN, an LSTM also has a hidden state where H(t-1) represents the hidden state of the previous timestamp and Ht is the hidden state of the current timestamp. In addition to that, LSTM also has a cell state represented by C(t-1) and C(t) for the previous and current timestamps, respectively.

Bidirectional LSTMs (Long Short-Term Memory) are a type of recurrent neural network (RNN) architecture that processes input data in both forward and backward directions. In a traditional LSTM, the information flows only from past to future, making predictions based on the preceding context. However, in bidirectional LSTMs, the network also considers future context, enabling it to capture dependencies in both directions.

The bidirectional LSTM comprises two LSTM layers, one processing the input sequence in the forward direction and the other in the backward direction. This allows the network to access information from past and future time steps simultaneously. As a result, bidirectional LSTMs are particularly useful for tasks that require a comprehensive understanding of the input sequence, such as natural language processing tasks like sentiment analysis, machine translation, and named entity recognition.

By incorporating information from both directions, bidirectional LSTMs enhance the model’s ability to capture long-term dependencies and make more accurate predictions in complex sequential data.
"""

# %%
print(f"Total characters including blank space : {len(text_data)}")
print(f"Total words : {len(text_data.split())}")
# Out:
# Total characters including blank space : 4773
# Total words : 753

# %%
sentences = re.split(r'[.\n]', text_data)
#sentences

# %%
# Logic - if word having blank space then it will return 0 and it is then i have to exclude  it
print([1 if sentences[5].strip() else 0])

sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
# Out:
# [0]

# %%
sentences[:40]
# Out:
# ['Long Short-Term Memory Networks is a deep learning, sequential neural network that allows information to persist',
#  'It is a special type of Recurrent Neural Network which is capable of handling the vanishing gradient problem faced by RNN',
#  'LSTM was designed by Hochreiter and Schmidhuber that resolves the problem caused by traditional rnns and machine learning algorithms',
#  'LSTM can be implemented in Python using the Keras library',
#  'Let’s say while watching a video, you remember the previous scene, or while reading a book, you know what happened in the earlier chapter',
#  'RNNs work similarly; they remember the previous information and use it for processing the current input',
#  'The shortcoming of RNN is they cannot remember long-term dependencies due to vanishing gradient',
#  'LSTMs are explicitly designed to avoid long-term dependency problems',
#  'This article will cover all the basics about LSTM, including its meaning, architecture, applications, and gates',
#  'Learning Objectives',
#  'Understand what LSTM is',
#  'Understand the architecture and working of an LSTM network',
#  'Learn about the different parts/gates in an LSTM unit',
#  'Note: If you are more interested in learning concepts in an Audio-Visual format, We have the tutorial of this entire article explained in the video below',
#  'If not, you may continue reading',
#  'Table of contents',
#  'What is LSTM?',
#  'LSTM Architecture',
#  'Forget Gate',
#  'Input Gate',
#  'New Information',
#  'Output Gate',
#  'LTSM vs RNN',
#  'What are Bidirectional LSTMs?',
#  'Conclusion',
#  'Frequently Asked Questions',
#  'What is LSTM?',
#  'LSTM (Long Short-Term Memory) is a recurrent neural network (RNN) architecture widely used in Deep Learning',
#  'It excels at capturing long-term dependencies, making it ideal for sequence prediction tasks',
#  'Unlike traditional neural networks, LSTM incorporates feedback connections, allowing it to process entire sequences of data, not just individual data points',
#  'This makes it highly effective in understanding and predicting patterns in sequential data like time series, text, and speech',
#  'In the introduction to long short-term memory, we learned that it resolves the vanishing gradient problem faced by RNN, so now, in this section, we will see how it resolves this problem by learning the architecture of the LSTM',
#  'At a high level, LSTM works very much like an RNN cell',
#  'Here is the internal functioning of the LSTM network',
#  'The LSTM network architecture consists of three parts, as shown in the image below, and each part performs an individual function',
#  'The first part chooses whether the information coming from the previous timestamp is to be remembered or is irrelevant and can be forgotten',
#  'In the second part, the cell tries to learn new information from the input to this cell',
#  'At last, in the third part, the cell passes the updated information from the current timestamp to the next timestamp',
#  'This one cycle of LSTM is considered a single-time step',
#  'These three parts of an LSTM unit are known as gates']

# %%
# Tokenization

from keras.preprocessing.text import Tokenizer
# Out:
# 2023-11-25 23:31:48.363171: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-25 23:31:48.450053: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-25 23:31:48.451369: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-25 23:31:50.017982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(sentences)

# %%
print("\nTokenized Word with index")
tokenizer.word_index
# Out:
# Tokenized Word with index
# {'the': 1,
#  'lstm': 2,
#  'in': 3,
#  'and': 4,
#  'of': 5,
#  'a': 6,
#  'is': 7,
#  'to': 8,
#  'network': 9,
#  'information': 10,
#  'it': 11,
#  'cell': 12,
#  'long': 13,
#  'term': 14,
#  'rnn': 15,
#  'this': 16,
#  'an': 17,
#  'gate': 18,
#  'that': 19,
#  'by': 20,
#  'input': 21,
#  'architecture': 22,
#  'memory': 23,
#  'learning': 24,
#  'neural': 25,
#  'lstms': 26,
#  'are': 27,
#  'bidirectional': 28,
#  'as': 29,
#  'from': 30,
#  'previous': 31,
#  'what': 32,
#  'current': 33,
#  'data': 34,
#  'timestamp': 35,
#  'state': 36,
#  'short': 37,
#  'problem': 38,
#  'traditional': 39,
#  'be': 40,
#  'you': 41,
#  'or': 42,
#  'for': 43,
#  'dependencies': 44,
#  'gates': 45,
#  'like': 46,
#  'part': 47,
#  'hidden': 48,
#  'sequential': 49,
#  'recurrent': 50,
#  'vanishing': 51,
#  'gradient': 52,
#  'resolves': 53,
#  'can': 54,
#  'remember': 55,
#  'they': 56,
#  'processing': 57,
#  'parts': 58,
#  'unit': 59,
#  'we': 60,
#  'at': 61,
#  'sequence': 62,
#  'tasks': 63,
#  'time': 64,
#  'three': 65,
#  'one': 66,
#  'also': 67,
#  't': 68,
#  'both': 69,
#  'directions': 70,
#  'future': 71,
#  'networks': 72,
#  'deep': 73,
#  'allows': 74,
#  'type': 75,
#  'faced': 76,
#  'designed': 77,
#  'rnns': 78,
#  'machine': 79,
#  'while': 80,
#  'video': 81,
#  'reading': 82,
#  'article': 83,
#  'will': 84,
#  'about': 85,
#  'understand': 86,
#  'learn': 87,
#  'if': 88,
#  'more': 89,
#  'entire': 90,
#  'below': 91,
#  'not': 92,
#  'forget': 93,
#  'new': 94,
#  'output': 95,
#  'making': 96,
#  'just': 97,
#  'individual': 98,
#  'understanding': 99,
#  'consists': 100,
#  'each': 101,
#  'first': 102,
#  'second': 103,
#  'last': 104,
#  'considered': 105,
#  'these': 106,
#  'known': 107,
#  'layer': 108,
#  'has': 109,
#  '1': 110,
#  'c': 111,
#  'forward': 112,
#  'backward': 113,
#  'past': 114,
#  'predictions': 115,
#  'context': 116,
#  'capture': 117,
#  'direction': 118,
#  'persist': 119,
#  'special': 120,
#  'which': 121,
#  'capable': 122,
#  'handling': 123,
#  'was': 124,
#  'hochreiter': 125,
#  'schmidhuber': 126,
#  'caused': 127,
#  'algorithms': 128,
#  'implemented': 129,
#  'python': 130,
#  'using': 131,
#  'keras': 132,
#  'library': 133,
#  'let’s': 134,
#  'say': 135,
#  'watching': 136,
#  'scene': 137,
#  'book': 138,
#  'know': 139,
#  'happened': 140,
#  'earlier': 141,
#  'chapter': 142,
#  'work': 143,
#  'similarly': 144,
#  'use': 145,
#  'shortcoming': 146,
#  'cannot': 147,
#  'due': 148,
#  'explicitly': 149,
#  'avoid': 150,
#  'dependency': 151,
#  'problems': 152,
#  'cover': 153,
#  'all': 154,
#  'basics': 155,
#  'including': 156,
#  'its': 157,
#  'meaning': 158,
#  'applications': 159,
#  'objectives': 160,
#  'working': 161,
#  'different': 162,
#  'note': 163,
#  'interested': 164,
#  'concepts': 165,
#  'audio': 166,
#  'visual': 167,
#  'format': 168,
#  'have': 169,
#  'tutorial': 170,
#  'explained': 171,
#  'may': 172,
#  'continue': 173,
#  'table': 174,
#  'contents': 175,
#  'ltsm': 176,
#  'vs': 177,
#  'conclusion': 178,
#  'frequently': 179,
#  'asked': 180,
#  'questions': 181,
#  'widely': 182,
#  'used': 183,
#  'excels': 184,
#  'capturing': 185,
#  'ideal': 186,
#  'prediction': 187,
#  'unlike': 188,
#  'incorporates': 189,
#  'feedback': 190,
#  'connections': 191,
#  'allowing': 192,
#  'process': 193,
#  'sequences': 194,
#  'points': 195,
#  'makes': 196,
#  'highly': 197,
#  'effective': 198,
#  'predicting': 199,
#  'patterns': 200,
#  'series': 201,
#  'text': 202,
#  'speech': 203,
#  'introduction': 204,
#  'learned': 205,
#  'so': 206,
#  'now': 207,
#  'section': 208,
#  'see': 209,
#  'how': 210,
#  'high': 211,
#  'level': 212,
#  'works': 213,
#  'very': 214,
#  'much': 215,
#  'here': 216,
#  'internal': 217,
#  'functioning': 218,
#  'shown': 219,
#  'image': 220,
#  'performs': 221,
#  'function': 222,
#  'chooses': 223,
#  'whether': 224,
#  'coming': 225,
#  'remembered': 226,
#  'irrelevant': 227,
#  'forgotten': 228,
#  'tries': 229,
#  'third': 230,
#  'passes': 231,
#  'updated': 232,
#  'next': 233,
#  'cycle': 234,
#  'single': 235,
#  'step': 236,
#  'control': 237,
#  'flow': 238,
#  'out': 239,
#  'called': 240,
#  'neurons': 241,
#  'feedforward': 242,
#  'with': 243,
#  'neuron': 244,
#  'having': 245,
#  'simple': 246,
#  'where': 247,
#  'h': 248,
#  'represents': 249,
#  'ht': 250,
#  'addition': 251,
#  'represented': 252,
#  'timestamps': 253,
#  'respectively': 254,
#  'processes': 255,
#  'flows': 256,
#  'only': 257,
#  'based': 258,
#  'on': 259,
#  'preceding': 260,
#  'however': 261,
#  'considers': 262,
#  'enabling': 263,
#  'comprises': 264,
#  'two': 265,
#  'layers': 266,
#  'other': 267,
#  'access': 268,
#  'steps': 269,
#  'simultaneously': 270,
#  'result': 271,
#  'particularly': 272,
#  'useful': 273,
#  'require': 274,
#  'comprehensive': 275,
#  'such': 276,
#  'natural': 277,
#  'language': 278,
#  'sentiment': 279,
#  'analysis': 280,
#  'translation': 281,
#  'named': 282,
#  'entity': 283,
#  'recognition': 284,
#  'incorporating': 285,
#  'enhance': 286,
#  'model’s': 287,
#  'ability': 288,
#  'make': 289,
#  'accurate': 290,
#  'complex': 291}

# %%
print("\nNo. of occurence of each word")
tokenizer.word_counts
# Out:
# No. of occurence of each word
# OrderedDict([('long', 8),
#              ('short', 4),
#              ('term', 8),
#              ('memory', 6),
#              ('networks', 2),
#              ('is', 16),
#              ('a', 18),
#              ('deep', 2),
#              ('learning', 6),
#              ('sequential', 3),
#              ('neural', 6),
#              ('network', 10),
#              ('that', 7),
#              ('allows', 2),
#              ('information', 10),
#              ('to', 14),
#              ('persist', 1),
#              ('it', 9),
#              ('special', 1),
#              ('type', 2),
#              ('of', 20),
#              ('recurrent', 3),
#              ('which', 1),
#              ('capable', 1),
#              ('handling', 1),
#              ('the', 55),
#              ('vanishing', 3),
#              ('gradient', 3),
#              ('problem', 4),
#              ('faced', 2),
#              ('by', 7),
#              ('rnn', 8),
#              ('lstm', 25),
#              ('was', 1),
#              ('designed', 2),
#              ('hochreiter', 1),
#              ('and', 21),
#              ('schmidhuber', 1),
#              ('resolves', 3),
#              ('caused', 1),
#              ('traditional', 4),
#              ('rnns', 2),
#              ('machine', 2),
#              ('algorithms', 1),
#              ('can', 3),
#              ('be', 4),
#              ('implemented', 1),
#              ('in', 24),
#              ('python', 1),
#              ('using', 1),
#              ('keras', 1),
#              ('library', 1),
#              ('let’s', 1),
#              ('say', 1),
#              ('while', 2),
#              ('watching', 1),
#              ('video', 2),
#              ('you', 4),
#              ('remember', 3),
#              ('previous', 5),
#              ('scene', 1),
#              ('or', 4),
#              ('reading', 2),
#              ('book', 1),
#              ('know', 1),
#              ('what', 5),
#              ('happened', 1),
#              ('earlier', 1),
#              ('chapter', 1),
#              ('work', 1),
#              ('similarly', 1),
#              ('they', 3),
#              ('use', 1),
#              ('for', 4),
#              ('processing', 3),
#              ('current', 5),
#              ('input', 7),
#              ('shortcoming', 1),
#              ('cannot', 1),
#              ('dependencies', 4),
#              ('due', 1),
#              ('lstms', 6),
#              ('are', 6),
#              ('explicitly', 1),
#              ('avoid', 1),
#              ('dependency', 1),
#              ('problems', 1),
#              ('this', 8),
#              ('article', 2),
#              ('will', 2),
#              ('cover', 1),
#              ('all', 1),
#              ('basics', 1),
#              ('about', 2),
#              ('including', 1),
#              ('its', 1),
#              ('meaning', 1),
#              ('architecture', 7),
#              ('applications', 1),
#              ('gates', 4),
#              ('objectives', 1),
#              ('understand', 2),
#              ('working', 1),
#              ('an', 8),
#              ('learn', 2),
#              ('different', 1),
#              ('parts', 3),
#              ('unit', 3),
#              ('note', 1),
#              ('if', 2),
#              ('more', 2),
#              ('interested', 1),
#              ('concepts', 1),
#              ('audio', 1),
#              ('visual', 1),
#              ('format', 1),
#              ('we', 3),
#              ('have', 1),
#              ('tutorial', 1),
#              ('entire', 2),
#              ('explained', 1),
#              ('below', 2),
#              ('not', 2),
#              ('may', 1),
#              ('continue', 1),
#              ('table', 1),
#              ('contents', 1),
#              ('forget', 2),
#              ('gate', 8),
#              ('new', 2),
#              ('output', 2),
#              ('ltsm', 1),
#              ('vs', 1),
#              ('bidirectional', 6),
#              ('conclusion', 1),
#              ('frequently', 1),
#              ('asked', 1),
#              ('questions', 1),
#              ('widely', 1),
#              ('used', 1),
#              ('excels', 1),
#              ('at', 3),
#              ('capturing', 1),
#              ('making', 2),
#              ('ideal', 1),
#              ('sequence', 3),
#              ('prediction', 1),
#              ('tasks', 3),
#              ('unlike', 1),
#              ('incorporates', 1),
#              ('feedback', 1),
#              ('connections', 1),
#              ('allowing', 1),
#              ('process', 1),
#              ('sequences', 1),
#              ('data', 5),
#              ('just', 2),
#              ('individual', 2),
#              ('points', 1),
#              ('makes', 1),
#              ('highly', 1),
#              ('effective', 1),
#              ('understanding', 2),
#              ('predicting', 1),
#              ('patterns', 1),
#              ('like', 4),
#              ('time', 3),
#              ('series', 1),
#              ('text', 1),
#              ('speech', 1),
#              ('introduction', 1),
#              ('learned', 1),
#              ('so', 1),
#              ('now', 1),
#              ('section', 1),
#              ('see', 1),
#              ('how', 1),
#              ('high', 1),
#              ('level', 1),
#              ('works', 1),
#              ('very', 1),
#              ('much', 1),
#              ('cell', 9),
#              ('here', 1),
#              ('internal', 1),
#              ('functioning', 1),
#              ('consists', 2),
#              ('three', 3),
#              ('as', 6),
#              ('shown', 1),
#              ('image', 1),
#              ('each', 2),
#              ('part', 4),
#              ('performs', 1),
#              ('function', 1),
#              ('first', 2),
#              ('chooses', 1),
#              ('whether', 1),
#              ('coming', 1),
#              ('from', 6),
#              ('timestamp', 5),
#              ('remembered', 1),
#              ('irrelevant', 1),
#              ('forgotten', 1),
#              ('second', 2),
#              ('tries', 1),
#              ('last', 2),
#              ('third', 1),
#              ('passes', 1),
#              ('updated', 1),
#              ('next', 1),
#              ('one', 3),
#              ('cycle', 1),
#              ('considered', 2),
#              ('single', 1),
#              ('step', 1),
#              ('these', 2),
#              ('known', 2),
#              ('control', 1),
#              ('flow', 1),
#              ('out', 1),
#              ('called', 1),
#              ('layer', 2),
#              ('neurons', 1),
#              ('feedforward', 1),
#              ('with', 1),
#              ('neuron', 1),
#              ('having', 1),
#              ('hidden', 4),
#              ('state', 5),
#              ('simple', 1),
#              ('also', 3),
#              ('has', 2),
#              ('where', 1),
#              ('h', 1),
#              ('t', 3),
#              ('1', 2),
#              ('represents', 1),
#              ('ht', 1),
#              ('addition', 1),
#              ('represented', 1),
#              ('c', 2),
#              ('timestamps', 1),
#              ('respectively', 1),
#              ('processes', 1),
#              ('both', 3),
#              ('forward', 2),
#              ('backward', 2),
#              ('directions', 3),
#              ('flows', 1),
#              ('only', 1),
#              ('past', 2),
#              ('future', 3),
#              ('predictions', 2),
#              ('based', 1),
#              ('on', 1),
#              ('preceding', 1),
#              ('context', 2),
#              ('however', 1),
#              ('considers', 1),
#              ('enabling', 1),
#              ('capture', 2),
#              ('comprises', 1),
#              ('two', 1),
#              ('layers', 1),
#              ('direction', 2),
#              ('other', 1),
#              ('access', 1),
#              ('steps', 1),
#              ('simultaneously', 1),
#              ('result', 1),
#              ('particularly', 1),
#              ('useful', 1),
#              ('require', 1),
#              ('comprehensive', 1),
#              ('such', 1),
#              ('natural', 1),
#              ('language', 1),
#              ('sentiment', 1),
#              ('analysis', 1),
#              ('translation', 1),
#              ('named', 1),
#              ('entity', 1),
#              ('recognition', 1),
#              ('incorporating', 1),
#              ('enhance', 1),
#              ('model’s', 1),
#              ('ability', 1),
#              ('make', 1),
#              ('accurate', 1),
#              ('complex', 1)])

# %%
print("Total Unique words : ",len(tokenizer.word_counts))
# Out:
# Total Unique words :  291

# %%
# Table of input and output
# eg : for sentence : He plays Cricket
# input       output
# He          plays
# He plays    Cricket


input_sentences = []

for sentence in sentences:
    tokenized_sequence = tokenizer.texts_to_sequences([sentence])[0]
    
    for i in range(1,len(tokenized_sequence)):
        input_sentences.append(tokenized_sequence[:i+1])

# %%
input_sentences
# Out:
# [[13, 37],
#  [13, 37, 14],
#  [13, 37, 14, 23],
#  [13, 37, 14, 23, 72],
#  [13, 37, 14, 23, 72, 7],
#  [13, 37, 14, 23, 72, 7, 6],
#  [13, 37, 14, 23, 72, 7, 6, 73],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49, 25],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49, 25, 9],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49, 25, 9, 19],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49, 25, 9, 19, 74],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49, 25, 9, 19, 74, 10],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49, 25, 9, 19, 74, 10, 8],
#  [13, 37, 14, 23, 72, 7, 6, 73, 24, 49, 25, 9, 19, 74, 10, 8, 119],
#  [11, 7],
#  [11, 7, 6],
#  [11, 7, 6, 120],
#  [11, 7, 6, 120, 75],
#  [11, 7, 6, 120, 75, 5],
#  [11, 7, 6, 120, 75, 5, 50],
#  [11, 7, 6, 120, 75, 5, 50, 25],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5, 123],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5, 123, 1],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5, 123, 1, 51],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5, 123, 1, 51, 52],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5, 123, 1, 51, 52, 38],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5, 123, 1, 51, 52, 38, 76],
#  [11, 7, 6, 120, 75, 5, 50, 25, 9, 121, 7, 122, 5, 123, 1, 51, 52, 38, 76, 20],
#  [11,
#   7,
#   6,
#   120,
#   75,
#   5,
#   50,
#   25,
#   9,
#   121,
#   7,
#   122,
#   5,
#   123,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15],
#  [2, 124],
#  [2, 124, 77],
#  [2, 124, 77, 20],
#  [2, 124, 77, 20, 125],
#  [2, 124, 77, 20, 125, 4],
#  [2, 124, 77, 20, 125, 4, 126],
#  [2, 124, 77, 20, 125, 4, 126, 19],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127, 20],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127, 20, 39],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127, 20, 39, 78],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127, 20, 39, 78, 4],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127, 20, 39, 78, 4, 79],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127, 20, 39, 78, 4, 79, 24],
#  [2, 124, 77, 20, 125, 4, 126, 19, 53, 1, 38, 127, 20, 39, 78, 4, 79, 24, 128],
#  [2, 54],
#  [2, 54, 40],
#  [2, 54, 40, 129],
#  [2, 54, 40, 129, 3],
#  [2, 54, 40, 129, 3, 130],
#  [2, 54, 40, 129, 3, 130, 131],
#  [2, 54, 40, 129, 3, 130, 131, 1],
#  [2, 54, 40, 129, 3, 130, 131, 1, 132],
#  [2, 54, 40, 129, 3, 130, 131, 1, 132, 133],
#  [134, 135],
#  [134, 135, 80],
#  [134, 135, 80, 136],
#  [134, 135, 80, 136, 6],
#  [134, 135, 80, 136, 6, 81],
#  [134, 135, 80, 136, 6, 81, 41],
#  [134, 135, 80, 136, 6, 81, 41, 55],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137, 42],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137, 42, 80],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137, 42, 80, 82],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137, 42, 80, 82, 6],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137, 42, 80, 82, 6, 138],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137, 42, 80, 82, 6, 138, 41],
#  [134, 135, 80, 136, 6, 81, 41, 55, 1, 31, 137, 42, 80, 82, 6, 138, 41, 139],
#  [134,
#   135,
#   80,
#   136,
#   6,
#   81,
#   41,
#   55,
#   1,
#   31,
#   137,
#   42,
#   80,
#   82,
#   6,
#   138,
#   41,
#   139,
#   32],
#  [134,
#   135,
#   80,
#   136,
#   6,
#   81,
#   41,
#   55,
#   1,
#   31,
#   137,
#   42,
#   80,
#   82,
#   6,
#   138,
#   41,
#   139,
#   32,
#   140],
#  [134,
#   135,
#   80,
#   136,
#   6,
#   81,
#   41,
#   55,
#   1,
#   31,
#   137,
#   42,
#   80,
#   82,
#   6,
#   138,
#   41,
#   139,
#   32,
#   140,
#   3],
#  [134,
#   135,
#   80,
#   136,
#   6,
#   81,
#   41,
#   55,
#   1,
#   31,
#   137,
#   42,
#   80,
#   82,
#   6,
#   138,
#   41,
#   139,
#   32,
#   140,
#   3,
#   1],
#  [134,
#   135,
#   80,
#   136,
#   6,
#   81,
#   41,
#   55,
#   1,
#   31,
#   137,
#   42,
#   80,
#   82,
#   6,
#   138,
#   41,
#   139,
#   32,
#   140,
#   3,
#   1,
#   141],
#  [134,
#   135,
#   80,
#   136,
#   6,
#   81,
#   41,
#   55,
#   1,
#   31,
#   137,
#   42,
#   80,
#   82,
#   6,
#   138,
#   41,
#   139,
#   32,
#   140,
#   3,
#   1,
#   141,
#   142],
#  [78, 143],
#  [78, 143, 144],
#  [78, 143, 144, 56],
#  [78, 143, 144, 56, 55],
#  [78, 143, 144, 56, 55, 1],
#  [78, 143, 144, 56, 55, 1, 31],
#  [78, 143, 144, 56, 55, 1, 31, 10],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4, 145],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4, 145, 11],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4, 145, 11, 43],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4, 145, 11, 43, 57],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4, 145, 11, 43, 57, 1],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4, 145, 11, 43, 57, 1, 33],
#  [78, 143, 144, 56, 55, 1, 31, 10, 4, 145, 11, 43, 57, 1, 33, 21],
#  [1, 146],
#  [1, 146, 5],
#  [1, 146, 5, 15],
#  [1, 146, 5, 15, 7],
#  [1, 146, 5, 15, 7, 56],
#  [1, 146, 5, 15, 7, 56, 147],
#  [1, 146, 5, 15, 7, 56, 147, 55],
#  [1, 146, 5, 15, 7, 56, 147, 55, 13],
#  [1, 146, 5, 15, 7, 56, 147, 55, 13, 14],
#  [1, 146, 5, 15, 7, 56, 147, 55, 13, 14, 44],
#  [1, 146, 5, 15, 7, 56, 147, 55, 13, 14, 44, 148],
#  [1, 146, 5, 15, 7, 56, 147, 55, 13, 14, 44, 148, 8],
#  [1, 146, 5, 15, 7, 56, 147, 55, 13, 14, 44, 148, 8, 51],
#  [1, 146, 5, 15, 7, 56, 147, 55, 13, 14, 44, 148, 8, 51, 52],
#  [26, 27],
#  [26, 27, 149],
#  [26, 27, 149, 77],
#  [26, 27, 149, 77, 8],
#  [26, 27, 149, 77, 8, 150],
#  [26, 27, 149, 77, 8, 150, 13],
#  [26, 27, 149, 77, 8, 150, 13, 14],
#  [26, 27, 149, 77, 8, 150, 13, 14, 151],
#  [26, 27, 149, 77, 8, 150, 13, 14, 151, 152],
#  [16, 83],
#  [16, 83, 84],
#  [16, 83, 84, 153],
#  [16, 83, 84, 153, 154],
#  [16, 83, 84, 153, 154, 1],
#  [16, 83, 84, 153, 154, 1, 155],
#  [16, 83, 84, 153, 154, 1, 155, 85],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2, 156],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2, 156, 157],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2, 156, 157, 158],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2, 156, 157, 158, 22],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2, 156, 157, 158, 22, 159],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2, 156, 157, 158, 22, 159, 4],
#  [16, 83, 84, 153, 154, 1, 155, 85, 2, 156, 157, 158, 22, 159, 4, 45],
#  [24, 160],
#  [86, 32],
#  [86, 32, 2],
#  [86, 32, 2, 7],
#  [86, 1],
#  [86, 1, 22],
#  [86, 1, 22, 4],
#  [86, 1, 22, 4, 161],
#  [86, 1, 22, 4, 161, 5],
#  [86, 1, 22, 4, 161, 5, 17],
#  [86, 1, 22, 4, 161, 5, 17, 2],
#  [86, 1, 22, 4, 161, 5, 17, 2, 9],
#  [87, 85],
#  [87, 85, 1],
#  [87, 85, 1, 162],
#  [87, 85, 1, 162, 58],
#  [87, 85, 1, 162, 58, 45],
#  [87, 85, 1, 162, 58, 45, 3],
#  [87, 85, 1, 162, 58, 45, 3, 17],
#  [87, 85, 1, 162, 58, 45, 3, 17, 2],
#  [87, 85, 1, 162, 58, 45, 3, 17, 2, 59],
#  [163, 88],
#  [163, 88, 41],
#  [163, 88, 41, 27],
#  [163, 88, 41, 27, 89],
#  [163, 88, 41, 27, 89, 164],
#  [163, 88, 41, 27, 89, 164, 3],
#  [163, 88, 41, 27, 89, 164, 3, 24],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17, 166],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17, 166, 167],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17, 166, 167, 168],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17, 166, 167, 168, 60],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17, 166, 167, 168, 60, 169],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17, 166, 167, 168, 60, 169, 1],
#  [163, 88, 41, 27, 89, 164, 3, 24, 165, 3, 17, 166, 167, 168, 60, 169, 1, 170],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16,
#   90],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16,
#   90,
#   83],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16,
#   90,
#   83,
#   171],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16,
#   90,
#   83,
#   171,
#   3],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16,
#   90,
#   83,
#   171,
#   3,
#   1],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16,
#   90,
#   83,
#   171,
#   3,
#   1,
#   81],
#  [163,
#   88,
#   41,
#   27,
#   89,
#   164,
#   3,
#   24,
#   165,
#   3,
#   17,
#   166,
#   167,
#   168,
#   60,
#   169,
#   1,
#   170,
#   5,
#   16,
#   90,
#   83,
#   171,
#   3,
#   1,
#   81,
#   91],
#  [88, 92],
#  [88, 92, 41],
#  [88, 92, 41, 172],
#  [88, 92, 41, 172, 173],
#  [88, 92, 41, 172, 173, 82],
#  [174, 5],
#  [174, 5, 175],
#  [32, 7],
#  [32, 7, 2],
#  [2, 22],
#  [93, 18],
#  [21, 18],
#  [94, 10],
#  [95, 18],
#  [176, 177],
#  [176, 177, 15],
#  [32, 27],
#  [32, 27, 28],
#  [32, 27, 28, 26],
#  [179, 180],
#  [179, 180, 181],
#  [32, 7],
#  [32, 7, 2],
#  [2, 13],
#  [2, 13, 37],
#  [2, 13, 37, 14],
#  [2, 13, 37, 14, 23],
#  [2, 13, 37, 14, 23, 7],
#  [2, 13, 37, 14, 23, 7, 6],
#  [2, 13, 37, 14, 23, 7, 6, 50],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9, 15],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9, 15, 22],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9, 15, 22, 182],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9, 15, 22, 182, 183],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9, 15, 22, 182, 183, 3],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9, 15, 22, 182, 183, 3, 73],
#  [2, 13, 37, 14, 23, 7, 6, 50, 25, 9, 15, 22, 182, 183, 3, 73, 24],
#  [11, 184],
#  [11, 184, 61],
#  [11, 184, 61, 185],
#  [11, 184, 61, 185, 13],
#  [11, 184, 61, 185, 13, 14],
#  [11, 184, 61, 185, 13, 14, 44],
#  [11, 184, 61, 185, 13, 14, 44, 96],
#  [11, 184, 61, 185, 13, 14, 44, 96, 11],
#  [11, 184, 61, 185, 13, 14, 44, 96, 11, 186],
#  [11, 184, 61, 185, 13, 14, 44, 96, 11, 186, 43],
#  [11, 184, 61, 185, 13, 14, 44, 96, 11, 186, 43, 62],
#  [11, 184, 61, 185, 13, 14, 44, 96, 11, 186, 43, 62, 187],
#  [11, 184, 61, 185, 13, 14, 44, 96, 11, 186, 43, 62, 187, 63],
#  [188, 39],
#  [188, 39, 25],
#  [188, 39, 25, 72],
#  [188, 39, 25, 72, 2],
#  [188, 39, 25, 72, 2, 189],
#  [188, 39, 25, 72, 2, 189, 190],
#  [188, 39, 25, 72, 2, 189, 190, 191],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8, 193],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8, 193, 90],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8, 193, 90, 194],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8, 193, 90, 194, 5],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8, 193, 90, 194, 5, 34],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8, 193, 90, 194, 5, 34, 92],
#  [188, 39, 25, 72, 2, 189, 190, 191, 192, 11, 8, 193, 90, 194, 5, 34, 92, 97],
#  [188,
#   39,
#   25,
#   72,
#   2,
#   189,
#   190,
#   191,
#   192,
#   11,
#   8,
#   193,
#   90,
#   194,
#   5,
#   34,
#   92,
#   97,
#   98],
#  [188,
#   39,
#   25,
#   72,
#   2,
#   189,
#   190,
#   191,
#   192,
#   11,
#   8,
#   193,
#   90,
#   194,
#   5,
#   34,
#   92,
#   97,
#   98,
#   34],
#  [188,
#   39,
#   25,
#   72,
#   2,
#   189,
#   190,
#   191,
#   192,
#   11,
#   8,
#   193,
#   90,
#   194,
#   5,
#   34,
#   92,
#   97,
#   98,
#   34,
#   195],
#  [16, 196],
#  [16, 196, 11],
#  [16, 196, 11, 197],
#  [16, 196, 11, 197, 198],
#  [16, 196, 11, 197, 198, 3],
#  [16, 196, 11, 197, 198, 3, 99],
#  [16, 196, 11, 197, 198, 3, 99, 4],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3, 49],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3, 49, 34],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3, 49, 34, 46],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3, 49, 34, 46, 64],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3, 49, 34, 46, 64, 201],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3, 49, 34, 46, 64, 201, 202],
#  [16, 196, 11, 197, 198, 3, 99, 4, 199, 200, 3, 49, 34, 46, 64, 201, 202, 4],
#  [16,
#   196,
#   11,
#   197,
#   198,
#   3,
#   99,
#   4,
#   199,
#   200,
#   3,
#   49,
#   34,
#   46,
#   64,
#   201,
#   202,
#   4,
#   203],
#  [3, 1],
#  [3, 1, 204],
#  [3, 1, 204, 8],
#  [3, 1, 204, 8, 13],
#  [3, 1, 204, 8, 13, 37],
#  [3, 1, 204, 8, 13, 37, 14],
#  [3, 1, 204, 8, 13, 37, 14, 23],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11, 53],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11, 53, 1],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11, 53, 1, 51],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11, 53, 1, 51, 52],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11, 53, 1, 51, 52, 38],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11, 53, 1, 51, 52, 38, 76],
#  [3, 1, 204, 8, 13, 37, 14, 23, 60, 205, 19, 11, 53, 1, 51, 52, 38, 76, 20],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38,
#   20],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38,
#   20,
#   24],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38,
#   20,
#   24,
#   1],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38,
#   20,
#   24,
#   1,
#   22],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38,
#   20,
#   24,
#   1,
#   22,
#   5],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38,
#   20,
#   24,
#   1,
#   22,
#   5,
#   1],
#  [3,
#   1,
#   204,
#   8,
#   13,
#   37,
#   14,
#   23,
#   60,
#   205,
#   19,
#   11,
#   53,
#   1,
#   51,
#   52,
#   38,
#   76,
#   20,
#   15,
#   206,
#   207,
#   3,
#   16,
#   208,
#   60,
#   84,
#   209,
#   210,
#   11,
#   53,
#   16,
#   38,
#   20,
#   24,
#   1,
#   22,
#   5,
#   1,
#   2],
#  [61, 6],
#  [61, 6, 211],
#  [61, 6, 211, 212],
#  [61, 6, 211, 212, 2],
#  [61, 6, 211, 212, 2, 213],
#  [61, 6, 211, 212, 2, 213, 214],
#  [61, 6, 211, 212, 2, 213, 214, 215],
#  [61, 6, 211, 212, 2, 213, 214, 215, 46],
#  [61, 6, 211, 212, 2, 213, 214, 215, 46, 17],
#  [61, 6, 211, 212, 2, 213, 214, 215, 46, 17, 15],
#  [61, 6, 211, 212, 2, 213, 214, 215, 46, 17, 15, 12],
#  [216, 7],
#  [216, 7, 1],
#  [216, 7, 1, 217],
#  [216, 7, 1, 217, 218],
#  [216, 7, 1, 217, 218, 5],
#  [216, 7, 1, 217, 218, 5, 1],
#  [216, 7, 1, 217, 218, 5, 1, 2],
#  [216, 7, 1, 217, 218, 5, 1, 2, 9],
#  [1, 2],
#  [1, 2, 9],
#  [1, 2, 9, 22],
#  [1, 2, 9, 22, 100],
#  [1, 2, 9, 22, 100, 5],
#  [1, 2, 9, 22, 100, 5, 65],
#  [1, 2, 9, 22, 100, 5, 65, 58],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1, 220],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1, 220, 91],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1, 220, 91, 4],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1, 220, 91, 4, 101],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1, 220, 91, 4, 101, 47],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1, 220, 91, 4, 101, 47, 221],
#  [1, 2, 9, 22, 100, 5, 65, 58, 29, 219, 3, 1, 220, 91, 4, 101, 47, 221, 17],
#  [1,
#   2,
#   9,
#   22,
#   100,
#   5,
#   65,
#   58,
#   29,
#   219,
#   3,
#   1,
#   220,
#   91,
#   4,
#   101,
#   47,
#   221,
#   17,
#   98],
#  [1,
#   2,
#   9,
#   22,
#   100,
#   5,
#   65,
#   58,
#   29,
#   219,
#   3,
#   1,
#   220,
#   91,
#   4,
#   101,
#   47,
#   221,
#   17,
#   98,
#   222],
#  [1, 102],
#  [1, 102, 47],
#  [1, 102, 47, 223],
#  [1, 102, 47, 223, 224],
#  [1, 102, 47, 223, 224, 1],
#  [1, 102, 47, 223, 224, 1, 10],
#  [1, 102, 47, 223, 224, 1, 10, 225],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35, 7],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35, 7, 8],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35, 7, 8, 40],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35, 7, 8, 40, 226],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35, 7, 8, 40, 226, 42],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35, 7, 8, 40, 226, 42, 7],
#  [1, 102, 47, 223, 224, 1, 10, 225, 30, 1, 31, 35, 7, 8, 40, 226, 42, 7, 227],
#  [1,
#   102,
#   47,
#   223,
#   224,
#   1,
#   10,
#   225,
#   30,
#   1,
#   31,
#   35,
#   7,
#   8,
#   40,
#   226,
#   42,
#   7,
#   227,
#   4],
#  [1,
#   102,
#   47,
#   223,
#   224,
#   1,
#   10,
#   225,
#   30,
#   1,
#   31,
#   35,
#   7,
#   8,
#   40,
#   226,
#   42,
#   7,
#   227,
#   4,
#   54],
#  [1,
#   102,
#   47,
#   223,
#   224,
#   1,
#   10,
#   225,
#   30,
#   1,
#   31,
#   35,
#   7,
#   8,
#   40,
#   226,
#   42,
#   7,
#   227,
#   4,
#   54,
#   40],
#  [1,
#   102,
#   47,
#   223,
#   224,
#   1,
#   10,
#   225,
#   30,
#   1,
#   31,
#   35,
#   7,
#   8,
#   40,
#   226,
#   42,
#   7,
#   227,
#   4,
#   54,
#   40,
#   228],
#  [3, 1],
#  [3, 1, 103],
#  [3, 1, 103, 47],
#  [3, 1, 103, 47, 1],
#  [3, 1, 103, 47, 1, 12],
#  [3, 1, 103, 47, 1, 12, 229],
#  [3, 1, 103, 47, 1, 12, 229, 8],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94, 10],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94, 10, 30],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94, 10, 30, 1],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94, 10, 30, 1, 21],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94, 10, 30, 1, 21, 8],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94, 10, 30, 1, 21, 8, 16],
#  [3, 1, 103, 47, 1, 12, 229, 8, 87, 94, 10, 30, 1, 21, 8, 16, 12],
#  [61, 104],
#  [61, 104, 3],
#  [61, 104, 3, 1],
#  [61, 104, 3, 1, 230],
#  [61, 104, 3, 1, 230, 47],
#  [61, 104, 3, 1, 230, 47, 1],
#  [61, 104, 3, 1, 230, 47, 1, 12],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10, 30],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10, 30, 1],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10, 30, 1, 33],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10, 30, 1, 33, 35],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10, 30, 1, 33, 35, 8],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10, 30, 1, 33, 35, 8, 1],
#  [61, 104, 3, 1, 230, 47, 1, 12, 231, 1, 232, 10, 30, 1, 33, 35, 8, 1, 233],
#  [61,
#   104,
#   3,
#   1,
#   230,
#   47,
#   1,
#   12,
#   231,
#   1,
#   232,
#   10,
#   30,
#   1,
#   33,
#   35,
#   8,
#   1,
#   233,
#   35],
#  [16, 66],
#  [16, 66, 234],
#  [16, 66, 234, 5],
#  [16, 66, 234, 5, 2],
#  [16, 66, 234, 5, 2, 7],
#  [16, 66, 234, 5, 2, 7, 105],
#  [16, 66, 234, 5, 2, 7, 105, 6],
#  [16, 66, 234, 5, 2, 7, 105, 6, 235],
#  [16, 66, 234, 5, 2, 7, 105, 6, 235, 64],
#  [16, 66, 234, 5, 2, 7, 105, 6, 235, 64, 236],
#  [106, 65],
#  [106, 65, 58],
#  [106, 65, 58, 5],
#  [106, 65, 58, 5, 17],
#  [106, 65, 58, 5, 17, 2],
#  [106, 65, 58, 5, 17, 2, 59],
#  [106, 65, 58, 5, 17, 2, 59, 27],
#  [106, 65, 58, 5, 17, 2, 59, 27, 107],
#  [106, 65, 58, 5, 17, 2, 59, 27, 107, 29],
#  [106, 65, 58, 5, 17, 2, 59, 27, 107, 29, 45],
#  [56, 237],
#  [56, 237, 1],
#  [56, 237, 1, 238],
#  [56, 237, 1, 238, 5],
#  [56, 237, 1, 238, 5, 10],
#  [56, 237, 1, 238, 5, 10, 3],
#  [56, 237, 1, 238, 5, 10, 3, 4],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239, 5],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239, 5, 1],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239, 5, 1, 23],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239, 5, 1, 23, 12],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239, 5, 1, 23, 12, 42],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239, 5, 1, 23, 12, 42, 2],
#  [56, 237, 1, 238, 5, 10, 3, 4, 239, 5, 1, 23, 12, 42, 2, 12],
#  [1, 102],
#  [1, 102, 18],
#  [1, 102, 18, 7],
#  [1, 102, 18, 7, 240],
#  [1, 102, 18, 7, 240, 93],
#  [1, 102, 18, 7, 240, 93, 18],
#  [1, 102, 18, 7, 240, 93, 18, 1],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107, 29],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107, 29, 1],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107, 29, 1, 21],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107, 29, 1, 21, 18],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107, 29, 1, 21, 18, 4],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107, 29, 1, 21, 18, 4, 1],
#  [1, 102, 18, 7, 240, 93, 18, 1, 103, 18, 7, 107, 29, 1, 21, 18, 4, 1, 104],
#  [1,
#   102,
#   18,
#   7,
#   240,
#   93,
#   18,
#   1,
#   103,
#   18,
#   7,
#   107,
#   29,
#   1,
#   21,
#   18,
#   4,
#   1,
#   104,
#   66],
#  [1,
#   102,
#   18,
#   7,
#   240,
#   93,
#   18,
#   1,
#   103,
#   18,
#   7,
#   107,
#   29,
#   1,
#   21,
#   18,
#   4,
#   1,
#   104,
#   66,
#   7],
#  [1,
#   102,
#   18,
#   7,
#   240,
#   93,
#   18,
#   1,
#   103,
#   18,
#   7,
#   107,
#   29,
#   1,
#   21,
#   18,
#   4,
#   1,
#   104,
#   66,
#   7,
#   1],
#  [1,
#   102,
#   18,
#   7,
#   240,
#   93,
#   18,
#   1,
#   103,
#   18,
#   7,
#   107,
#   29,
#   1,
#   21,
#   18,
#   4,
#   1,
#   104,
#   66,
#   7,
#   1,
#   95],
#  [1,
#   102,
#   18,
#   7,
#   240,
#   93,
#   18,
#   1,
#   103,
#   18,
#   7,
#   107,
#   29,
#   1,
#   21,
#   18,
#   4,
#   1,
#   104,
#   66,
#   7,
#   1,
#   95,
#   18],
#  [17, 2],
#  [17, 2, 59],
#  [17, 2, 59, 19],
#  [17, 2, 59, 19, 100],
#  [17, 2, 59, 19, 100, 5],
#  [17, 2, 59, 19, 100, 5, 106],
#  [17, 2, 59, 19, 100, 5, 106, 65],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23, 12],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23, 12, 42],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23, 12, 42, 2],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23, 12, 42, 2, 12],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23, 12, 42, 2, 12, 54],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23, 12, 42, 2, 12, 54, 40],
#  [17, 2, 59, 19, 100, 5, 106, 65, 45, 4, 6, 23, 12, 42, 2, 12, 54, 40, 105],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245,
#   6],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245,
#   6,
#   48],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245,
#   6,
#   48,
#   108],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245,
#   6,
#   48,
#   108,
#   4],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245,
#   6,
#   48,
#   108,
#   4,
#   6],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245,
#   6,
#   48,
#   108,
#   4,
#   6,
#   33],
#  [17,
#   2,
#   59,
#   19,
#   100,
#   5,
#   106,
#   65,
#   45,
#   4,
#   6,
#   23,
#   12,
#   42,
#   2,
#   12,
#   54,
#   40,
#   105,
#   29,
#   6,
#   108,
#   5,
#   241,
#   3,
#   39,
#   242,
#   25,
#   9,
#   243,
#   101,
#   244,
#   245,
#   6,
#   48,
#   108,
#   4,
#   6,
#   33,
#   36],
#  [97, 46],
#  [97, 46, 6],
#  [97, 46, 6, 246],
#  [97, 46, 6, 246, 15],
#  [97, 46, 6, 246, 15, 17],
#  [97, 46, 6, 246, 15, 17, 2],
#  [97, 46, 6, 246, 15, 17, 2, 67],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48, 36],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48, 36, 247],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48, 36, 247, 248],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48, 36, 247, 248, 68],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48, 36, 247, 248, 68, 110],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48, 36, 247, 248, 68, 110, 249],
#  [97, 46, 6, 246, 15, 17, 2, 67, 109, 6, 48, 36, 247, 248, 68, 110, 249, 1],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7,
#   1],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7,
#   1,
#   48],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7,
#   1,
#   48,
#   36],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7,
#   1,
#   48,
#   36,
#   5],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7,
#   1,
#   48,
#   36,
#   5,
#   1],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7,
#   1,
#   48,
#   36,
#   5,
#   1,
#   33],
#  [97,
#   46,
#   6,
#   246,
#   15,
#   17,
#   2,
#   67,
#   109,
#   6,
#   48,
#   36,
#   247,
#   248,
#   68,
#   110,
#   249,
#   1,
#   48,
#   36,
#   5,
#   1,
#   31,
#   35,
#   4,
#   250,
#   7,
#   1,
#   48,
#   36,
#   5,
#   1,
#   33,
#   35],
#  [3, 251],
#  [3, 251, 8],
#  [3, 251, 8, 19],
#  [3, 251, 8, 19, 2],
#  [3, 251, 8, 19, 2, 67],
#  [3, 251, 8, 19, 2, 67, 109],
#  [3, 251, 8, 19, 2, 67, 109, 6],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20, 111],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20, 111, 68],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20, 111, 68, 110],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20, 111, 68, 110, 4],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20, 111, 68, 110, 4, 111],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20, 111, 68, 110, 4, 111, 68],
#  [3, 251, 8, 19, 2, 67, 109, 6, 12, 36, 252, 20, 111, 68, 110, 4, 111, 68, 43],
#  [3,
#   251,
#   8,
#   19,
#   2,
#   67,
#   109,
#   6,
#   12,
#   36,
#   252,
#   20,
#   111,
#   68,
#   110,
#   4,
#   111,
#   68,
#   43,
#   1],
#  [3,
#   251,
#   8,
#   19,
#   2,
#   67,
#   109,
#   6,
#   12,
#   36,
#   252,
#   20,
#   111,
#   68,
#   110,
#   4,
#   111,
#   68,
#   43,
#   1,
#   31],
#  [3,
#   251,
#   8,
#   19,
#   2,
#   67,
#   109,
#   6,
#   12,
#   36,
#   252,
#   20,
#   111,
#   68,
#   110,
#   4,
#   111,
#   68,
#   43,
#   1,
#   31,
#   4],
#  [3,
#   251,
#   8,
#   19,
#   2,
#   67,
#   109,
#   6,
#   12,
#   36,
#   252,
#   20,
#   111,
#   68,
#   110,
#   4,
#   111,
#   68,
#   43,
#   1,
#   31,
#   4,
#   33],
#  [3,
#   251,
#   8,
#   19,
#   2,
#   67,
#   109,
#   6,
#   12,
#   36,
#   252,
#   20,
#   111,
#   68,
#   110,
#   4,
#   111,
#   68,
#   43,
#   1,
#   31,
#   4,
#   33,
#   253],
#  [3,
#   251,
#   8,
#   19,
#   2,
#   67,
#   109,
#   6,
#   12,
#   36,
#   252,
#   20,
#   111,
#   68,
#   110,
#   4,
#   111,
#   68,
#   43,
#   1,
#   31,
#   4,
#   33,
#   253,
#   254],
#  [28, 26],
#  [28, 26, 13],
#  [28, 26, 13, 37],
#  [28, 26, 13, 37, 14],
#  [28, 26, 13, 37, 14, 23],
#  [28, 26, 13, 37, 14, 23, 27],
#  [28, 26, 13, 37, 14, 23, 27, 6],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9, 15],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9, 15, 22],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9, 15, 22, 19],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9, 15, 22, 19, 255],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9, 15, 22, 19, 255, 21],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9, 15, 22, 19, 255, 21, 34],
#  [28, 26, 13, 37, 14, 23, 27, 6, 75, 5, 50, 25, 9, 15, 22, 19, 255, 21, 34, 3],
#  [28,
#   26,
#   13,
#   37,
#   14,
#   23,
#   27,
#   6,
#   75,
#   5,
#   50,
#   25,
#   9,
#   15,
#   22,
#   19,
#   255,
#   21,
#   34,
#   3,
#   69],
#  [28,
#   26,
#   13,
#   37,
#   14,
#   23,
#   27,
#   6,
#   75,
#   5,
#   50,
#   25,
#   9,
#   15,
#   22,
#   19,
#   255,
#   21,
#   34,
#   3,
#   69,
#   112],
#  [28,
#   26,
#   13,
#   37,
#   14,
#   23,
#   27,
#   6,
#   75,
#   5,
#   50,
#   25,
#   9,
#   15,
#   22,
#   19,
#   255,
#   21,
#   34,
#   3,
#   69,
#   112,
#   4],
#  [28,
#   26,
#   13,
#   37,
#   14,
#   23,
#   27,
#   6,
#   75,
#   5,
#   50,
#   25,
#   9,
#   15,
#   22,
#   19,
#   255,
#   21,
#   34,
#   3,
#   69,
#   112,
#   4,
#   113],
#  [28,
#   26,
#   13,
#   37,
#   14,
#   23,
#   27,
#   6,
#   75,
#   5,
#   50,
#   25,
#   9,
#   15,
#   22,
#   19,
#   255,
#   21,
#   34,
#   3,
#   69,
#   112,
#   4,
#   113,
#   70],
#  [3, 6],
#  [3, 6, 39],
#  [3, 6, 39, 2],
#  [3, 6, 39, 2, 1],
#  [3, 6, 39, 2, 1, 10],
#  [3, 6, 39, 2, 1, 10, 256],
#  [3, 6, 39, 2, 1, 10, 256, 257],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8, 71],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8, 71, 96],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8, 71, 96, 115],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8, 71, 96, 115, 258],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8, 71, 96, 115, 258, 259],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8, 71, 96, 115, 258, 259, 1],
#  [3, 6, 39, 2, 1, 10, 256, 257, 30, 114, 8, 71, 96, 115, 258, 259, 1, 260],
#  [3,
#   6,
#   39,
#   2,
#   1,
#   10,
#   256,
#   257,
#   30,
#   114,
#   8,
#   71,
#   96,
#   115,
#   258,
#   259,
#   1,
#   260,
#   116],
#  [261, 3],
#  [261, 3, 28],
#  [261, 3, 28, 26],
#  [261, 3, 28, 26, 1],
#  [261, 3, 28, 26, 1, 9],
#  [261, 3, 28, 26, 1, 9, 67],
#  [261, 3, 28, 26, 1, 9, 67, 262],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263, 11],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263, 11, 8],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263, 11, 8, 117],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263, 11, 8, 117, 44],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263, 11, 8, 117, 44, 3],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263, 11, 8, 117, 44, 3, 69],
#  [261, 3, 28, 26, 1, 9, 67, 262, 71, 116, 263, 11, 8, 117, 44, 3, 69, 70],
#  [1, 28],
#  [1, 28, 2],
#  [1, 28, 2, 264],
#  [1, 28, 2, 264, 265],
#  [1, 28, 2, 264, 265, 2],
#  [1, 28, 2, 264, 265, 2, 266],
#  [1, 28, 2, 264, 265, 2, 266, 66],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3, 1],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3, 1, 112],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3, 1, 112, 118],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3, 1, 112, 118, 4],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3, 1, 112, 118, 4, 1],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3, 1, 112, 118, 4, 1, 267],
#  [1, 28, 2, 264, 265, 2, 266, 66, 57, 1, 21, 62, 3, 1, 112, 118, 4, 1, 267, 3],
#  [1,
#   28,
#   2,
#   264,
#   265,
#   2,
#   266,
#   66,
#   57,
#   1,
#   21,
#   62,
#   3,
#   1,
#   112,
#   118,
#   4,
#   1,
#   267,
#   3,
#   1],
#  [1,
#   28,
#   2,
#   264,
#   265,
#   2,
#   266,
#   66,
#   57,
#   1,
#   21,
#   62,
#   3,
#   1,
#   112,
#   118,
#   4,
#   1,
#   267,
#   3,
#   1,
#   113],
#  [1,
#   28,
#   2,
#   264,
#   265,
#   2,
#   266,
#   66,
#   57,
#   1,
#   21,
#   62,
#   3,
#   1,
#   112,
#   118,
#   4,
#   1,
#   267,
#   3,
#   1,
#   113,
#   118],
#  [16, 74],
#  [16, 74, 1],
#  [16, 74, 1, 9],
#  [16, 74, 1, 9, 8],
#  [16, 74, 1, 9, 8, 268],
#  [16, 74, 1, 9, 8, 268, 10],
#  [16, 74, 1, 9, 8, 268, 10, 30],
#  [16, 74, 1, 9, 8, 268, 10, 30, 114],
#  [16, 74, 1, 9, 8, 268, 10, 30, 114, 4],
#  [16, 74, 1, 9, 8, 268, 10, 30, 114, 4, 71],
#  [16, 74, 1, 9, 8, 268, 10, 30, 114, 4, 71, 64],
#  [16, 74, 1, 9, 8, 268, 10, 30, 114, 4, 71, 64, 269],
#  [16, 74, 1, 9, 8, 268, 10, 30, 114, 4, 71, 64, 269, 270],
#  [29, 6],
#  [29, 6, 271],
#  [29, 6, 271, 28],
#  [29, 6, 271, 28, 26],
#  [29, 6, 271, 28, 26, 27],
#  [29, 6, 271, 28, 26, 27, 272],
#  [29, 6, 271, 28, 26, 27, 272, 273],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274, 6],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274, 6, 275],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274, 6, 275, 99],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274, 6, 275, 99, 5],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274, 6, 275, 99, 5, 1],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274, 6, 275, 99, 5, 1, 21],
#  [29, 6, 271, 28, 26, 27, 272, 273, 43, 63, 19, 274, 6, 275, 99, 5, 1, 21, 62],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279,
#   280],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279,
#   280,
#   79],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279,
#   280,
#   79,
#   281],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279,
#   280,
#   79,
#   281,
#   4],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279,
#   280,
#   79,
#   281,
#   4,
#   282],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279,
#   280,
#   79,
#   281,
#   4,
#   282,
#   283],
#  [29,
#   6,
#   271,
#   28,
#   26,
#   27,
#   272,
#   273,
#   43,
#   63,
#   19,
#   274,
#   6,
#   275,
#   99,
#   5,
#   1,
#   21,
#   62,
#   276,
#   29,
#   277,
#   278,
#   57,
#   63,
#   46,
#   279,
#   280,
#   79,
#   281,
#   4,
#   282,
#   283,
#   284],
#  [20, 285],
#  [20, 285, 10],
#  [20, 285, 10, 30],
#  [20, 285, 10, 30, 69],
#  [20, 285, 10, 30, 69, 70],
#  [20, 285, 10, 30, 69, 70, 28],
#  [20, 285, 10, 30, 69, 70, 28, 26],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287, 288],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287, 288, 8],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287, 288, 8, 117],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287, 288, 8, 117, 13],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287, 288, 8, 117, 13, 14],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287, 288, 8, 117, 13, 14, 44],
#  [20, 285, 10, 30, 69, 70, 28, 26, 286, 1, 287, 288, 8, 117, 13, 14, 44, 4],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289,
#   89],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289,
#   89,
#   290],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289,
#   89,
#   290,
#   115],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289,
#   89,
#   290,
#   115,
#   3],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289,
#   89,
#   290,
#   115,
#   3,
#   291],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289,
#   89,
#   290,
#   115,
#   3,
#   291,
#   49],
#  [20,
#   285,
#   10,
#   30,
#   69,
#   70,
#   28,
#   26,
#   286,
#   1,
#   287,
#   288,
#   8,
#   117,
#   13,
#   14,
#   44,
#   4,
#   289,
#   89,
#   290,
#   115,
#   3,
#   291,
#   49,
#   34]]

# %%
print("Maximum word length in a sentence : ",max([len(x) for x in input_sentences]))
# Out:
# Maximum word length in a sentence :  40

# %%
# Padding 
from keras.utils import pad_sequences

# %%
padded_input_sentence = pad_sequences(input_sentences,padding='pre')

# %%
padded_input_sentence
# Out:
# array([[  0,   0,   0, ...,   0,  13,  37],
#        [  0,   0,   0, ...,  13,  37,  14],
#        [  0,   0,   0, ...,  37,  14,  23],
#        ...,
#        [  0,   0,   0, ..., 115,   3, 291],
#        [  0,   0,   0, ...,   3, 291,  49],
#        [  0,   0,   0, ..., 291,  49,  34]], dtype=int32)

# %%
X = padded_input_sentence[:,:-1]

# %%
X
# Out:
# array([[  0,   0,   0, ...,   0,   0,  13],
#        [  0,   0,   0, ...,   0,  13,  37],
#        [  0,   0,   0, ...,  13,  37,  14],
#        ...,
#        [  0,   0,   0, ..., 290, 115,   3],
#        [  0,   0,   0, ..., 115,   3, 291],
#        [  0,   0,   0, ...,   3, 291,  49]], dtype=int32)

# %%
y = padded_input_sentence[:,-1]

# %%
y[:50]
# Out:
# array([ 37,  14,  23,  72,   7,   6,  73,  24,  49,  25,   9,  19,  74,
#         10,   8, 119,   7,   6, 120,  75,   5,  50,  25,   9, 121,   7,
#        122,   5, 123,   1,  51,  52,  38,  76,  20,  15, 124,  77,  20,
#        125,   4, 126,  19,  53,   1,  38, 127,  20,  39,  78], dtype=int32)

# %%
# Applying one hot categorization
from keras.utils import to_categorical

# %%
y_pad = to_categorical(y,num_classes=292)

# %%
for i,c in enumerate(y_pad[0]):
    if c == float(1):
        print(i)
# Out:
# 37

# %%
for k,v in tokenizer.word_index.items():
    if v == 37:
        print(k)
# Out:
# short

# %%
X.shape
# Out:
# (717, 39)

# %%
y_pad.shape
# Out:
# (717, 292)

# %% [markdown]
# ## Model Architecture

# %%
from keras import Sequential
from keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential([
    Embedding(292,120,input_length=39), # total_words, define o/p dense no, input_length => highest count of word in sentence
    LSTM(150),  # 150 nodes for LSTM Timespam
    Dense(292,activation='softmax')  # total_words and activation fn
])
# Out:
# 2023-11-25 23:31:58.783822: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-25 23:31:58.789841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-25 23:31:58.793316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 39, 120)           35040
#
#  lstm (LSTM)                 (None, 150)               162600
#
#  dense (Dense)               (None, 292)               44092
#
# =================================================================
# Total params: 241,732
# Trainable params: 241,732
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X,y_pad,epochs=50)
# Out:
# Epoch 1/50
# 2023-11-25 23:31:59.724046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-25 23:31:59.727151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-25 23:31:59.729492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-25 23:32:01.359052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-25 23:32:01.363700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-25 23:32:01.368067: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 23/23 [==============================] - 6s 76ms/step - loss: 5.5232 - accuracy: 0.0474
# Epoch 2/50
# 23/23 [==============================] - 2s 76ms/step - loss: 5.2012 - accuracy: 0.0697
# Epoch 3/50
# 23/23 [==============================] - 2s 72ms/step - loss: 5.1097 - accuracy: 0.0697
# Epoch 4/50
# 23/23 [==============================] - 2s 77ms/step - loss: 5.0823 - accuracy: 0.0697
# Epoch 5/50
# 23/23 [==============================] - 2s 75ms/step - loss: 5.0584 - accuracy: 0.0697
# Epoch 6/50
# 23/23 [==============================] - 2s 75ms/step - loss: 5.0149 - accuracy: 0.0697
# Epoch 7/50
# 23/23 [==============================] - 2s 71ms/step - loss: 4.9430 - accuracy: 0.0697
# Epoch 8/50
# 23/23 [==============================] - 1s 64ms/step - loss: 4.8405 - accuracy: 0.0823
# Epoch 9/50
# 23/23 [==============================] - 1s 64ms/step - loss: 4.7193 - accuracy: 0.0893
# Epoch 10/50
# 23/23 [==============================] - 2s 75ms/step - loss: 4.5758 - accuracy: 0.1032
# Epoch 11/50
# 23/23 [==============================] - 2s 78ms/step - loss: 4.3926 - accuracy: 0.1199
# Epoch 12/50
# 23/23 [==============================] - 2s 66ms/step - loss: 4.1760 - accuracy: 0.1590
# Epoch 13/50
# 23/23 [==============================] - 2s 79ms/step - loss: 3.9498 - accuracy: 0.2022
# Epoch 14/50
# 23/23 [==============================] - 2s 66ms/step - loss: 3.7330 - accuracy: 0.2232
# Epoch 15/50
# 23/23 [==============================] - 2s 66ms/step - loss: 3.5067 - accuracy: 0.2510
# Epoch 16/50
# 23/23 [==============================] - 2s 67ms/step - loss: 3.2989 - accuracy: 0.3026
# Epoch 17/50
# 23/23 [==============================] - 2s 67ms/step - loss: 3.0791 - accuracy: 0.3389
# Epoch 18/50
# 23/23 [==============================] - 2s 66ms/step - loss: 2.8649 - accuracy: 0.3961
# Epoch 19/50
# 23/23 [==============================] - 2s 68ms/step - loss: 2.6752 - accuracy: 0.4268
# Epoch 20/50
# 23/23 [==============================] - 2s 67ms/step - loss: 2.4812 - accuracy: 0.4547
# Epoch 21/50
# 23/23 [==============================] - 2s 67ms/step - loss: 2.3119 - accuracy: 0.4868
# Epoch 22/50
# 23/23 [==============================] - 2s 68ms/step - loss: 2.1432 - accuracy: 0.5579
# Epoch 23/50
# 23/23 [==============================] - 2s 67ms/step - loss: 1.9931 - accuracy: 0.5927
# Epoch 24/50
# 23/23 [==============================] - 2s 69ms/step - loss: 1.8456 - accuracy: 0.6220
# Epoch 25/50
# 23/23 [==============================] - 2s 70ms/step - loss: 1.7014 - accuracy: 0.6695
# Epoch 26/50
# 23/23 [==============================] - 2s 69ms/step - loss: 1.5807 - accuracy: 0.7211
# Epoch 27/50
# 23/23 [==============================] - 2s 78ms/step - loss: 1.4644 - accuracy: 0.7517
# Epoch 28/50
# 23/23 [==============================] - 2s 74ms/step - loss: 1.3575 - accuracy: 0.7950
# Epoch 29/50
# 23/23 [==============================] - 2s 67ms/step - loss: 1.2586 - accuracy: 0.8257
# Epoch 30/50
# 23/23 [==============================] - 2s 67ms/step - loss: 1.1675 - accuracy: 0.8396
# Epoch 31/50
# 23/23 [==============================] - 2s 68ms/step - loss: 1.0842 - accuracy: 0.8619
# Epoch 32/50
# 23/23 [==============================] - 2s 69ms/step - loss: 1.0073 - accuracy: 0.8912
# Epoch 33/50
# 23/23 [==============================] - 2s 69ms/step - loss: 0.9281 - accuracy: 0.9038
# Epoch 34/50
# 23/23 [==============================] - 2s 69ms/step - loss: 0.8627 - accuracy: 0.9247
# Epoch 35/50
# 23/23 [==============================] - 2s 69ms/step - loss: 0.8040 - accuracy: 0.9317
# Epoch 36/50
# 23/23 [==============================] - 2s 73ms/step - loss: 0.7423 - accuracy: 0.9456
# Epoch 37/50
# 23/23 [==============================] - 2s 69ms/step - loss: 0.6902 - accuracy: 0.9498
# Epoch 38/50
# 23/23 [==============================] - 2s 68ms/step - loss: 0.6446 - accuracy: 0.9568
# Epoch 39/50
# 23/23 [==============================] - 2s 76ms/step - loss: 0.6041 - accuracy: 0.9582
# Epoch 40/50
# 23/23 [==============================] - 2s 85ms/step - loss: 0.5624 - accuracy: 0.9637
# Epoch 41/50
# 23/23 [==============================] - 2s 92ms/step - loss: 0.5272 - accuracy: 0.9609
# Epoch 42/50
# 23/23 [==============================] - 2s 99ms/step - loss: 0.4931 - accuracy: 0.9651
# Epoch 43/50
# 23/23 [==============================] - 2s 82ms/step - loss: 0.4637 - accuracy: 0.9679
# Epoch 44/50
# 23/23 [==============================] - 2s 86ms/step - loss: 0.4388 - accuracy: 0.9651
# Epoch 45/50
# 23/23 [==============================] - 2s 105ms/step - loss: 0.4114 - accuracy: 0.9693
# Epoch 46/50
# 23/23 [==============================] - 2s 92ms/step - loss: 0.3859 - accuracy: 0.9693
# Epoch 47/50
# 23/23 [==============================] - 2s 88ms/step - loss: 0.3640 - accuracy: 0.9707
# Epoch 48/50
# 23/23 [==============================] - 2s 89ms/step - loss: 0.3489 - accuracy: 0.9679
# Epoch 49/50
# 23/23 [==============================] - 2s 74ms/step - loss: 0.3285 - accuracy: 0.9707
# Epoch 50/50
# 23/23 [==============================] - 2s 81ms/step - loss: 0.3126 - accuracy: 0.9721

# %%
print(model.evaluate(X,y_pad))
# Out:
# 23/23 [==============================] - 2s 67ms/step - loss: 0.2864 - accuracy: 0.9763
# [0.2864013910293579, 0.9762901067733765]

# %% [markdown]
# ## Building Predictive system

# %%
import numpy as np
import time

# %%
input_text = "Unlike"

for n in range(1,10):

    # tokenization

    token_text = tokenizer.texts_to_sequences([input_text])[0]

    # padding

    padded_token_text = pad_sequences([token_text],maxlen=39,padding='pre')
    # print(padded_token_text)

    # prediction

    pos = np.argmax(model.predict(padded_token_text))
    # print(pos)

    for word,index in tokenizer.word_index.items():    
        if index == pos:
            input_text = input_text + " " + word
            time.sleep(1)
            print(input_text+ ".",end="\n\n")
# Out:
# 1/1 [==============================] - 0s 39ms/step
# Unlike traditional.
#
# 1/1 [==============================] - 0s 30ms/step
# Unlike traditional neural.
#
# 1/1 [==============================] - 0s 33ms/step
# Unlike traditional neural networks.
#
# 1/1 [==============================] - 0s 34ms/step
# Unlike traditional neural networks lstm.
#
# 1/1 [==============================] - 0s 31ms/step
# Unlike traditional neural networks lstm incorporates.
#
# 1/1 [==============================] - 0s 53ms/step
# Unlike traditional neural networks lstm incorporates feedback.
#
# 1/1 [==============================] - 0s 31ms/step
# Unlike traditional neural networks lstm incorporates feedback connections.
#
# 1/1 [==============================] - 0s 30ms/step
# Unlike traditional neural networks lstm incorporates feedback connections allowing.
#
# 1/1 [==============================] - 0s 52ms/step
# Unlike traditional neural networks lstm incorporates feedback connections allowing it.

# %%
#import joblib as jb

# %%
#jb.dump(model,'lstm_next_word.jb')

# %%
#jb.dump(tokenizer,'lstm_next_word_tokenizer.jb')
